-- %%
%sql
drop table if exists workspace.tpcds_sf1000_iceberg.call_center;
create table workspace.tpcds_sf1000_iceberg.call_center
using iceberg
as select * from samples.tpcds_sf1000.call_center;

drop table if exists workspace.tpcds_sf1000_iceberg.catalog_page;
create table workspace.tpcds_sf1000_iceberg.catalog_page
using iceberg
as select * from samples.tpcds_sf1000.catalog_page;

drop table if exists workspace.tpcds_sf1000_iceberg.catalog_returns;
create table workspace.tpcds_sf1000_iceberg.catalog_returns
using iceberg PARTITIONED BY (cr_returned_date_sk)
as select * from samples.tpcds_sf1000.catalog_returns;

drop table if exists workspace.tpcds_sf1000_iceberg.catalog_sales;
create table workspace.tpcds_sf1000_iceberg.catalog_sales
using iceberg PARTITIONED BY (cs_sold_date_sk)
as select * from samples.tpcds_sf1000.catalog_sales;

drop table if exists workspace.tpcds_sf1000_iceberg.customer;
create table workspace.tpcds_sf1000_iceberg.customer
using iceberg
as select * from samples.tpcds_sf1000.customer;

drop table if exists workspace.tpcds_sf1000_iceberg.customer_address;
create table workspace.tpcds_sf1000_iceberg.customer_address
using iceberg
as select * from samples.tpcds_sf1000.customer_address;

drop table if exists workspace.tpcds_sf1000_iceberg.customer_demographics;
create table workspace.tpcds_sf1000_iceberg.customer_demographics
using iceberg
as select * from samples.tpcds_sf1000.customer_demographics;

drop table if exists workspace.tpcds_sf1000_iceberg.date_dim;
create table workspace.tpcds_sf1000_iceberg.date_dim
using iceberg
as select * from samples.tpcds_sf1000.date_dim;

drop table if exists workspace.tpcds_sf1000_iceberg.household_demographics;
create table workspace.tpcds_sf1000_iceberg.household_demographics
using iceberg
as select * from samples.tpcds_sf1000.household_demographics;

drop table if exists workspace.tpcds_sf1000_iceberg.income_band;
create table workspace.tpcds_sf1000_iceberg.income_band
using iceberg
as select * from samples.tpcds_sf1000.income_band;

drop table if exists workspace.tpcds_sf1000_iceberg.inventory;
create table workspace.tpcds_sf1000_iceberg.inventory
using iceberg PARTITIONED BY (inv_date_sk)
as select * from samples.tpcds_sf1000.inventory;

drop table if exists workspace.tpcds_sf1000_iceberg.item;
create table workspace.tpcds_sf1000_iceberg.item
using iceberg
as select * from samples.tpcds_sf1000.item;

drop table if exists workspace.tpcds_sf1000_iceberg.promotion;
create table workspace.tpcds_sf1000_iceberg.promotion
using iceberg
as select * from samples.tpcds_sf1000.promotion;

drop table if exists workspace.tpcds_sf1000_iceberg.reason;
create table workspace.tpcds_sf1000_iceberg.reason
using iceberg
as select * from samples.tpcds_sf1000.reason;

drop table if exists workspace.tpcds_sf1000_iceberg.ship_mode;
create table workspace.tpcds_sf1000_iceberg.ship_mode
using iceberg
as select * from samples.tpcds_sf1000.ship_mode;

drop table if exists workspace.tpcds_sf1000_iceberg.store;
create table workspace.tpcds_sf1000_iceberg.store
using iceberg
as select * from samples.tpcds_sf1000.store;

drop table if exists workspace.tpcds_sf1000_iceberg.store_returns;
create table workspace.tpcds_sf1000_iceberg.store_returns
using iceberg PARTITIONED BY (sr_returned_date_sk)
as select * from samples.tpcds_sf1000.store_returns;

drop table if exists workspace.tpcds_sf1000_iceberg.store_sales;
create table workspace.tpcds_sf1000_iceberg.store_sales
using iceberg PARTITIONED BY (ss_sold_date_sk)
as select * from samples.tpcds_sf1000.store_sales;

drop table if exists workspace.tpcds_sf1000_iceberg.time_dim;
create table workspace.tpcds_sf1000_iceberg.time_dim
using iceberg
as select * from samples.tpcds_sf1000.time_dim;

drop table if exists workspace.tpcds_sf1000_iceberg.warehouse;
create table workspace.tpcds_sf1000_iceberg.warehouse
using iceberg
as select * from samples.tpcds_sf1000.warehouse;

drop table if exists workspace.tpcds_sf1000_iceberg.web_page;
create table workspace.tpcds_sf1000_iceberg.web_page
using iceberg
as select * from samples.tpcds_sf1000.web_page;

drop table if exists workspace.tpcds_sf1000_iceberg.web_returns;
create table workspace.tpcds_sf1000_iceberg.web_returns
using iceberg PARTITIONED BY (wr_returned_date_sk)
as select * from samples.tpcds_sf1000.web_returns;

drop table if exists workspace.tpcds_sf1000_iceberg.web_sales;
create table workspace.tpcds_sf1000_iceberg.web_sales
using iceberg PARTITIONED BY (ws_sold_date_sk)
as select * from samples.tpcds_sf1000.web_sales;

drop table if exists workspace.tpcds_sf1000_iceberg.web_site;
create table workspace.tpcds_sf1000_iceberg.web_site
using iceberg
as select * from samples.tpcds_sf1000.web_site;
