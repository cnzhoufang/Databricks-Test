# %%
# %sql
analyze workspace.tpcds_sf1000_iceberg.web_sales compute statistics;
analyze formatted samples.tpcds_sf1000.web_sales compute statistics;
analyze create table samples.tpcds_sf1000.call_center compute statistics;
analyze create table samples.tpcds_sf1000.catalog_page compute statistics;
analyze create table samples.tpcds_sf1000.catalog_returns compute statistics;
analyze create table samples.tpcds_sf1000.catalog_sales compute statistics;
analyze create table samples.tpcds_sf1000.customer compute statistics;
analyze create table samples.tpcds_sf1000.customer_address compute statistics;
analyze create table samples.tpcds_sf1000.customer_demographics compute statistics;
analyze create table samples.tpcds_sf1000.date_dim compute statistics;
analyze create table samples.tpcds_sf1000.household_demographics compute statistics;
analyze create table samples.tpcds_sf1000.income_band compute statistics;
analyze create table samples.tpcds_sf1000.inventory compute statistics;
analyze create table samples.tpcds_sf1000.item compute statistics;
analyze create table samples.tpcds_sf1000.promotion compute statistics;
analyze create table samples.tpcds_sf1000.reason compute statistics;
analyze create table samples.tpcds_sf1000.ship_mode compute statistics;
analyze create table samples.tpcds_sf1000.store compute statistics;
analyze create table samples.tpcds_sf1000.store_returns compute statistics;
analyze create table samples.tpcds_sf1000.store_sales compute statistics;
analyze create table samples.tpcds_sf1000.time_dim compute statistics;
analyze create table samples.tpcds_sf1000.warehouse compute statistics;
analyze create table samples.tpcds_sf1000.web_page compute statistics;
analyze create table samples.tpcds_sf1000.web_returns compute statistics;
analyze create table samples.tpcds_sf1000.web_sales compute statistics;
analyze create table samples.tpcds_sf1000.web_site compute statistics;
