# %%
# %sql
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.web_sales COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.web_sales COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.call_center COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.catalog_page COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.catalog_returns COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.catalog_sales COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.customer COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.customer_address COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.customer_demographics COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.date_dim COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.household_demographics COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.income_band COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.inventory COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.item COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.promotion COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.reason COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.ship_mode COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.store COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.store_returns COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.store_sales COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.time_dim COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.warehouse COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.web_page COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.web_returns COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.web_sales COMPUTE STATISTICS;
ANALYZE TABLE workspace.tpcds_sf1000_iceberg.web_site COMPUTE STATISTICS;
