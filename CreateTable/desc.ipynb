# %%
# %sql
-- desc formatted workspace.tpcds_sf1000_iceberg.web_sales;
-- desc formatted samples.tpcds_sf1000.web_sales;
-- show create table samples.tpcds_sf1000.call_center;
-- show create table samples.tpcds_sf1000.catalog_page;
-- show create table samples.tpcds_sf1000.catalog_returns;
-- show create table samples.tpcds_sf1000.catalog_sales;
-- show create table samples.tpcds_sf1000.customer;
-- show create table samples.tpcds_sf1000.customer_address;
-- show create table samples.tpcds_sf1000.customer_demographics;
--show create table samples.tpcds_sf1000.date_dim;
-- show create table samples.tpcds_sf1000.household_demographics;
-- show create table samples.tpcds_sf1000.income_band;
-- show create table samples.tpcds_sf1000.inventory;
--show create table samples.tpcds_sf1000.item;
-- show create table samples.tpcds_sf1000.promotion;
-- show create table samples.tpcds_sf1000.reason;
-- show create table samples.tpcds_sf1000.ship_mode;
--show create table samples.tpcds_sf1000.store;
--show create table samples.tpcds_sf1000.store_returns;
--show create table samples.tpcds_sf1000.store_sales;
--show create table samples.tpcds_sf1000.time_dim;
--show create table samples.tpcds_sf1000.warehouse;
--show create table samples.tpcds_sf1000.web_page;
--show create table samples.tpcds_sf1000.web_returns;
--show create table samples.tpcds_sf1000.web_sales;
-- show create table samples.tpcds_sf1000.web_site;
