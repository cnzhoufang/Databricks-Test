-- %%
SET use_cached_result = false;
SELECT  DISTINCT (
            i_product_name
)
FROM workspace.tpcds_sf1000_iceberg.item i1
WHERE   i_manufact_id BETWEEN 889 AND 889 + 40
AND     (
            SELECT  COUNT(*) AS item_cnt
            FROM workspace.tpcds_sf1000_iceberg.item
            WHERE   (
                        i_manufact = i1.i_manufact
                        AND     (
                                    (
                                                i_category = 'Women'
                                                AND     (
                                                            i_color = 'grey'
                                                            OR      i_color = 'salmon'
                                                )
                                                AND     (
                                                            i_units = 'Ounce'
                                                            OR      i_units = 'Pallet'
                                                )
                                                AND     (
                                                            i_size = 'small'
                                                            OR      i_size = 'extra large'
                                                )
                                    )
                                    OR      (
                                                i_category = 'Women'
                                                AND     (
                                                            i_color = 'ivory'
                                                            OR      i_color = 'royal'
                                                )
                                                AND     (
                                                            i_units = 'Cup'
                                                            OR      i_units = 'Each'
                                                )
                                                AND     (
                                                            i_size = 'large'
                                                            OR      i_size = 'N/A'
                                                )
                                    )
                                    OR      (
                                                i_category = 'Men'
                                                AND     (
                                                            i_color = 'orange'
                                                            OR      i_color = 'antique'
                                                )
                                                AND     (
                                                            i_units = 'Oz'
                                                            OR      i_units = 'Bundle'
                                                )
                                                AND     (
                                                            i_size = 'medium'
                                                            OR      i_size = 'economy'
                                                )
                                    )
                                    OR      (
                                                i_category = 'Men'
                                                AND     (
                                                            i_color = 'tan'
                                                            OR      i_color = 'azure'
                                                )
                                                AND     (
                                                            i_units = 'Box'
                                                            OR      i_units = 'Carton'
                                                )
                                                AND     (
                                                            i_size = 'small'
                                                            OR      i_size = 'extra large'
                                                )
                                    )
                        )
            )
            OR      (
                        i_manufact = i1.i_manufact
                        AND     (
                                    (
                                                i_category = 'Women'
                                                AND     (
                                                            i_color = 'rosy'
                                                            OR      i_color = 'hot'
                                                )
                                                AND     (
                                                            i_units = 'Case'
                                                            OR      i_units = 'Dram'
                                                )
                                                AND     (
                                                            i_size = 'small'
                                                            OR      i_size = 'extra large'
                                                )
                                    )
                                    OR      (
                                                i_category = 'Women'
                                                AND     (
                                                            i_color = 'coral'
                                                            OR      i_color = 'lime'
                                                )
                                                AND     (
                                                            i_units = 'Tbl'
                                                            OR      i_units = 'Dozen'
                                                )
                                                AND     (
                                                            i_size = 'large'
                                                            OR      i_size = 'N/A'
                                                )
                                    )
                                    OR      (
                                                i_category = 'Men'
                                                AND     (
                                                            i_color = 'tomato'
                                                            OR      i_color = 'white'
                                                )
                                                AND     (
                                                            i_units = 'Pound'
                                                            OR      i_units = 'Bunch'
                                                )
                                                AND     (
                                                            i_size = 'medium'
                                                            OR      i_size = 'economy'
                                                )
                                    )
                                    OR      (
                                                i_category = 'Men'
                                                AND     (
                                                            i_color = 'red'
                                                            OR      i_color = 'dark'
                                                )
                                                AND     (
                                                            i_units = 'Lb'
                                                            OR      i_units = 'Gram'
                                                )
                                                AND     (
                                                            i_size = 'small'
                                                            OR      i_size = 'extra large'
                                                )
                                    )
                        )
            )
        )  > 0
ORDER BY i_product_name
LIMIT   100
;
