-- %%
REFRESH TABLE samples.tpcds_sf1000.call_center;
REFRESH TABLE samples.tpcds_sf1000.catalog_page;
REFRESH TABLE samples.tpcds_sf1000.catalog_returns;
REFRESH TABLE samples.tpcds_sf1000.catalog_sales;
REFRESH TABLE samples.tpcds_sf1000.customer;
REFRESH TABLE samples.tpcds_sf1000.customer_address;
REFRESH TABLE samples.tpcds_sf1000.customer_demographics;
REFRESH TABLE samples.tpcds_sf1000.date_dim;
REFRESH TABLE samples.tpcds_sf1000.income_band;
REFRESH TABLE samples.tpcds_sf1000.inventory;
REFRESH TABLE samples.tpcds_sf1000.item;
REFRESH TABLE samples.tpcds_sf1000.promotion;
REFRESH TABLE samples.tpcds_sf1000.reason;
REFRESH TABLE samples.tpcds_sf1000.ship_mode;
REFRESH TABLE samples.tpcds_sf1000.store;
REFRESH TABLE samples.tpcds_sf1000.store_returns;
REFRESH TABLE samples.tpcds_sf1000.store_sales;
REFRESH TABLE samples.tpcds_sf1000.time_dim;
REFRESH TABLE samples.tpcds_sf1000.warehouse;
REFRESH TABLE samples.tpcds_sf1000.web_page;
REFRESH TABLE samples.tpcds_sf1000.web_returns;
REFRESH TABLE samples.tpcds_sf1000.web_sales;
REFRESH TABLE samples.tpcds_sf1000.web_site;
